s242 = [0.79684615, 0.021024918, 0.019906439, 0.006911443] 
s243 = [0.76081824, 0.036130764, 0.011578526, 0.0070112785] 
s244 = [0.67826056, 0.70203084, 0.79681516, 0.5906392] 

s245 = [0.6660035, 0.9761723, 0.6709115, 0.45477384] 
s246 = [0.8820274, 0.22914608, 0.034111924, 0.01833187] 
s247 = [0.7950987, 0.019001057, 0.0056355554, 0.0072946656]   
s248 = [0.75898385, 0.03508443, 0.026239676, 0.004036603] 
s249 = [0.6771905, 0.6990411, 0.7924389, 0.58840823]

# %%
for j in range(5):
    globals()['sil_highest_index_L{}'.format(j)] = []

for i in range(250):
    if i % 5 == 0:
        sil_highest_index_L0.append(globals()['s{}'.format(i)][1])
        
    elif i % 5 == 1:
        sil_highest_index_L1.append(globals()['s{}'.format(i)][0])
        
    elif i % 5 == 2:
        sil_highest_index_L2.append(globals()['s{}'.format(i)][0])
        
    elif i % 5 == 3:
        sil_highest_index_L3.append(globals()['s{}'.format(i)][0])
        
    elif i % 5 == 4:
        sil_highest_index_L4.append(globals()['s{}'.format(i)][2])

# %%
plt.figure(figsize=(10,8))

plt.plot(sil_highest_index_L0,label='Layer 1', linewidth=3)
plt.plot(sil_highest_index_L1,label='Layer 3', linewidth=3)
plt.plot(sil_highest_index_L2,label='Layer 5', linewidth=3)
plt.plot(sil_highest_index_L3,label='Layer 7', linewidth=3)
plt.plot(sil_highest_index_L4,label='Layer 8', linewidth=3)

plt.xlabel('Global epoch', fontsize=19)
plt.ylabel('Silhouette index s(i)', fontsize=19)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlim(0,40)

plt.grid(True)
plt.legend(fontsize=19)
plt.show()

# %%
labels = ['2','3','4','5' ]

def create_x(t, w, n, d):
    return [t*x + w*n for x in range(d)]

s245_x = create_x(5, 0.8, 1, 4)
s246_x = create_x(5, 0.8, 2, 4)
s247_x = create_x(5, 0.8, 3, 4)
s248_x = create_x(5, 0.8, 4, 4)
s249_x = create_x(5, 0.8, 5, 4)

plt.figure(figsize=(10,8))
ax = plt.subplot()
ax.bar(s245_x, s195, label='Layer 1', edgecolor='black', linewidth=1)
ax.bar(s246_x, s196, label='Layer 3', edgecolor='black', linewidth=1)
ax.bar(s247_x, s197, label='Layer 5', edgecolor='black', linewidth=1)
ax.bar(s248_x, s198, label='Layer 7', edgecolor='black', linewidth=1)
ax.bar(s249_x, s199, label='Layer 8', edgecolor='black', linewidth=1)

middle_x = [(a+b+c+d+e)/5 for (a,b,c,d,e) in zip(s245_x, s246_x, s247_x, s248_x, s249_x)]

ax.set_xticks(middle_x)
ax.set_xticklabels(labels, fontsize=15)
ax.set_yticklabels([0,0.2,0.4,0.6,0.8,1],fontsize=15)

ax.set_ylabel('Silhouette Index s(i)', fontsize=18)
ax.set_xlabel('Number of clusters', fontsize=18)

plt.grid(True)
plt.legend(fontsize=18)
plt.show()
# Out:
# <ipython-input-67-ffa6836bce42>:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([0,0.2,0.4,0.6,0.8,1],fontsize=15)

# %%
sp = [] 
sp.append(s245) 
sp.append(s246)
sp.append(s247)
sp.append(s248)
sp.append(s249)

sns.barplot(x=labels, y='d', hue='sex', data=sp) # default : dodge=True

plt.legend(fontsize=12)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-9246df05d79f> in <module>
#       6 sp.append(s249)
#       7
# ----> 8 sns.barplot(x=labels, y='d', hue='sex', data=sp) # default : dodge=True
#       9
#      10 plt.legend(fontsize=12)
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3177 ):
#    3178
# -> 3179     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
# ...
